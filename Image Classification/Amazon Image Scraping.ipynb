# %%
from selenium import webdriver
from webdriver_manager.firefox import GeckoDriverManager
import time
import csv
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import requests
import os

# %%
def img_scraper(product_name):
    driver = webdriver.Firefox(executable_path=GeckoDriverManager().install())
    driver.execute_script("window.open('');")
    driver.get('https://www.amazon.in')
    time.sleep(3)
    driver.find_element_by_xpath('//*[@id="twotabsearchtextbox"]').send_keys(product_name)
    driver.find_element_by_xpath('//*[@id="twotabsearchtextbox"]').send_keys(Keys.RETURN)
    time.sleep(5)
    print('Product Page opened')
    count = 0
    url = driver.current_url
    print(url)
    while count<200:
        html = driver.execute_script("return document.body.innerHTML;")
        time.sleep(5)
        soup = BeautifulSoup(html)
        print('HTML Parsed')
        urls = soup.findAll("a", {"class":"a-link-normal a-text-normal"})
        #print(urls)
        time.sleep(5)
        for i in urls:
            driver.switch_to.window(driver.window_handles[1])
            print('https://amazon.in'+i['href'])
            driver.get('https://amazon.in'+i['href'])
            time.sleep(5)
            src = driver.find_element_by_xpath('//*[@id="landingImage"]').get_attribute('src')
            urllib.request.urlretrieve(src, "{}/{}.jpeg".format(product_name, count))
            print('Image downloaded {}'.format(count))
            time.sleep(5)
            count = count+1
        print('Page Done, Opening next page')
        driver.switch_to.window(driver.window_handles[0])
        li = soup.find('li', {'class':'a-last'})
        url = 'https://www.amazon.in/' + li.find('a')['href']

# %%
img_scraper('saree')
# Out:
# [WDM] - Driver [/home/aditya/.wdm/drivers/geckodriver/linux64/v0.29.1/geckodriver] found in cache
# Product Page opened
# https://www.amazon.in/s?k=saree&ref=nb_sb_noss
# HTML Parsed
# https://amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A0204605UXNVEMSPR9T3&url=%2FMirraw-Relive-Womens-Blouse-Silk_Navy%2Fdp%2FB08Z28T88R%2Fref%3Dsr_1_1_sspa%3Fdchild%3D1%26keywords%3Dsaree%26qid%3D1623681514%26sr%3D8-1-spons%26psc%3D1&qualifier=1623681514&id=8023807705764353&widgetName=sp_atf
# Image downloaded 0
# https://amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A055280233XKNHPZXGTMB&url=%2FGlory-Sarees-Womens-Banarasi-kara128_red_Red%2Fdp%2FB08259WZWW%2Fref%3Dsr_1_2_sspa%3Fdchild%3D1%26keywords%3Dsaree%26qid%3D1623681514%26sr%3D8-2-spons%26psc%3D1&qualifier=1623681514&id=8023807705764353&widgetName=sp_atf
# Image downloaded 1
# ...

# %%
img_scraper('men trouser')
# Out:
# [WDM] - Driver [/home/aditya/.wdm/drivers/geckodriver/linux64/v0.29.1/geckodriver] found in cache
# Product Page opened
# https://www.amazon.in/s?k=men+trouser&ref=nb_sb_noss
# HTML Parsed
# https://amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A0860769AN5JK4ZBM9LX&url=%2FAmazon-Brand-Straight-INKJG-001_Olive_32W%2Fdp%2FB08FJNQMRY%2Fref%3Dsr_1_1_sspa%3Fdchild%3D1%26keywords%3Dmen%2Btrouser%26qid%3D1623684891%26sr%3D8-1-spons%26psc%3D1&qualifier=1623684891&id=3724548355717232&widgetName=sp_atf
# Image downloaded 0
# https://amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A01778791HO2F2CN2CRE0&url=%2FAmazon-Brand-Straight-INKCT-001_Navy_34W%2Fdp%2FB08FJNL7N3%2Fref%3Dsr_1_2_sspa%3Fdchild%3D1%26keywords%3Dmen%2Btrouser%26qid%3D1623684891%26sr%3D8-2-spons%26psc%3D1&qualifier=1623684891&id=3724548355717232&widgetName=sp_atf
# Image downloaded 1
# ...

# %%
img_scraper('men jeans')
# Out:
# [WDM] - Driver [/home/aditya/.wdm/drivers/geckodriver/linux64/v0.29.1/geckodriver] found in cache
# Product Page opened
# https://www.amazon.in/s?k=men+jeans&ref=nb_sb_noss
# HTML Parsed
# https://amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A0176755ZS0HBVMAEO9K&url=%2FAmazon-Brand-Inkast-Skinny-SK-164_Grey_34W%2Fdp%2FB07RHLVFG9%2Fref%3Dsr_1_1_sspa%3Fdchild%3D1%26keywords%3Dmen%2Bjeans%26qid%3D1623687655%26sr%3D8-1-spons%26psc%3D1&qualifier=1623687655&id=8391921267847617&widgetName=sp_atf
# Image downloaded 0
# https://amazon.in/gp/slredirect/picassoRedirect.html/ref=pa_sp_atf_aps_sr_pg1_1?ie=UTF8&adId=A01663793GOLTQUNMH86&url=%2FAmazon-Brand-Inkast-IK20-ST-52_Dark-Blue_34W%2Fdp%2FB083D9KDDL%2Fref%3Dsr_1_2_sspa%3Fdchild%3D1%26keywords%3Dmen%2Bjeans%26qid%3D1623687655%26sr%3D8-2-spons%26psc%3D1&qualifier=1623687655&id=8391921267847617&widgetName=sp_atf
# Image downloaded 1
# ...
